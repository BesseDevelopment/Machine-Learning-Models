# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import numpy as np 

X = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# %%
from linear_models.linear_regression import LinearRegression

model = LinearRegression(method="closed_form", solver="normal_equation")
model.fit(X, y)

# %%
print(model)
# Out:
# Model: Linear Regression
# Solution Method: closed_form
# Solver: normal_equation
# Intercept: [2.2]
# Coefficients: [0.6]
